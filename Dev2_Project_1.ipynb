# %%
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
from matplotlib.animation import FuncAnimation


data_url = "https://github.com/diegovalle/conapo-2010/raw/master/clean-data/state-population-age-groups.csv"
df = pd.read_csv(data_url, delimiter=',', encoding='latin1')  # Adjust the delimiter if needed
df
# Out:
#       AgeGroup  Females  Males   Total  Year  StateCode       StateName
# 0          0-4    58465  59075  117540  1990          1  Aguascalientes
# 1        10-14    51387  53154  104541  1990          1  Aguascalientes
# 2        15-19    48551  49798   98349  1990          1  Aguascalientes
# 3        20-24    42324  41992   84316  1990          1  Aguascalientes
# 4        25-29    34496  33603   68099  1990          1  Aguascalientes
# ...        ...      ...    ...     ...   ...        ...             ...
# 23611    65-69    32468  27728   60196  2030         32       Zacatecas
# 23612    70-74    24240  20337   44577  2030         32       Zacatecas
# 23613    75-79    16731  13843   30574  2030         32       Zacatecas
# 23614    80-84    10850   8796   19646  2030         32       Zacatecas
# 23615   85plus    11700   8935   20635  2030         32       Zacatecas
#
# [23616 rows x 7 columns]

# %%
! pip install bar_chart_race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import bar_chart_race as bcr
from IPython.display import HTML

# Sample data
data = {
    'Year': [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025,2026,2027,2028,2029,2030],
     'Aguascalientes': [824227, 844162, 863697, 882995, 902128, 921048, 939507, 957443, 974940, 991858, 1008447, 1025563, 1043783, 1062250, 1079814, 1096736, 1114099, 1133032, 1154011, 1175942, 1195788, 1215094, 1233920, 1252266, 1270174, 1287662, 1304741, 1321453, 1337793, 1353759, 1369306, 1384534, 1399529, 1414225, 1428616, 1442694, 1456433, 1469825, 1482859, 1495544, 1507808],
    'Baja California':[1732550, 1815903, 1895648, 1976271, 2058198, 2141231, 2224286, 2306424, 2387650, 2469220, 2549842, 2627368, 2702832, 2775926, 2845936, 2912674, 2977440, 3041783, 3105709, 3168319, 3224842, 3275399, 3328624, 3381078, 3432944, 3484150, 3534688, 3584606, 3633772, 3682064, 3729227, 3775765, 3822152, 3868004, 3913263, 3957876, 4001753, 4044848, 4087146, 4128624, 4169241],
    'Baja California Sur': [339387, 351246, 363307, 375535, 387994, 400667, 413575, 426653, 439911, 453340, 466455, 480190, 495522, 511831, 529124, 546776, 565024, 584639, 605343, 626900, 649616, 672682, 695410, 718196, 741038, 763930, 786865, 809833, 832827, 855836, 878832, 901820, 924811, 947776, 970702, 993576, 1016375, 1039076, 1061672, 1084143, 1106465],
    'Campeche':[553106, 568384, 583930, 599335, 614694, 629897, 644818, 659417, 673672, 687422, 700708, 714008, 727546, 741113, 754622, 768097, 781620, 795450, 809636, 824071, 836750, 852372, 866375, 880298, 894138, 907878, 921516, 935046, 948461, 961744, 974878, 987876, 1000756, 1013501, 1026110, 1038576, 1050893, 1063055, 1075067, 1086927, 1098636] ,
    'Chiapas': [3314875, 3395180, 3476913, 3559521, 3644811, 3732019, 3819739, 3907302, 3994325, 4083410, 4164853, 4239830, 4318948, 4397267, 4476586, 4549034, 4616199, 4688014, 4762080, 4836326, 4903755, 4980635, 5050570, 5119185, 5186573, 5252810, 5317959, 5382083, 5445234, 5507441, 5568647, 5628945, 5688426, 5747019, 5804709, 5861451, 5917180, 5971854, 6025462, 6077982, 6129220],
    'Chihuahua': [2408000, 2465322, 2521954, 2578946, 2636937, 2695309, 2753282, 2810765, 2868346, 2926998, 2987927, 3048688, 3107892, 3165454, 3218865, 3270309, 3322439, 3376544, 3431517, 3485093, 3525275, 3559249, 3598792, 3635964, 3673343, 3710129, 3746283, 3782020, 3816866, 3850427, 3882738, 3914405, 3945972, 3977086, 4007709, 4037776, 4067185, 4095912, 4123951, 4151279, 4177816],
    'Coahuila': [2005016, 2042564, 2080707, 2119320, 2158403, 2197744, 2237025, 2276268, 2315412, 2354430, 2393756, 2433242, 2472921, 2512261, 2550208, 2587518, 2625332, 2664019, 2703905, 2743966, 2782012, 2818078, 2854335, 2890107, 2925593, 2960681, 2995373, 3029739, 3063663, 3097014, 3129781, 3162054, 3193913, 3225277, 3256110, 3286368, 3316008, 3345007, 3373341, 3400990, 3427879],
    'Colima': [473115, 483048, 492181, 500880, 509258, 517359, 524947, 531965, 538560, 544150, 550291, 557968, 566389, 575411, 584151, 593827, 605061, 617146, 630606, 645050, 658910, 672263, 685395, 698296, 710981, 723455, 735724, 747801, 759689, 771375, 782832, 794144, 805404, 816553, 827586, 838498, 849280, 859931, 870444, 880824, 891052],
    'Distrito Federal': [8695562, 8738833, 8772275, 8801777, 8828375, 8853087, 8875396, 8895216, 8912913, 8928176, 8944935, 8961129, 8973544, 8982214, 8982860, 8980415, 8977954, 8973450, 8969421, 8961594, 8944600, 8928399, 8911666, 8893743, 8874723, 8854599, 8833418, 8811266, 8788142, 8764005, 8738915, 8712906, 8686004, 8658248, 8629650, 8600178, 8569825, 8538599, 8506513, 8473583, 8439787],
    'Durango': [1389199, 1402493, 1415393, 1427650, 1439646, 1451581, 1462829, 1472961, 1482259, 1488305, 1497613, 1511810, 1525797, 1540255, 1551703, 1566228, 1585478, 1605415, 1628321, 1650042, 1669813, 1690417, 1709742, 1728427, 1746806, 1764725, 1782204, 1799321, 1815965, 1832045, 1847547, 1862644, 1877504, 1892026, 1906215, 1920046, 1933498, 1946559, 1959235, 1971528, 1983391]

}

df = pd.DataFrame(data)

# Set 'Year' column as index
df.set_index('Year', inplace=True)

# Create the bar race chart
bcr.bar_chart_race(
    df=df,
    filename='bar_race_chart.mp4',
    orientation='h',
    sort='desc',
    n_bars=9,  # Set the number of bars (states) to display
    fixed_order=False,
    label_bars=True,
    steps_per_period=1,
    interpolate_period=False
)


# Display the video in the notebook
HTML('<video width="800" height="600" controls><source src="bar_race_chart.mp4" type="video/mp4"></video>')

#Codes taken from Youtube channel "Data/Fun" wth slight changes
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="800" height="600" controls><source src="bar_race_chart.mp4" type="video/mp4"></video>

# %%
from IPython.display import HTML
import base64

print("Play the video by clicking on the play button in the bottom left corner")

# Function to display video in Colab
def display_video(filename):
    video_file = open(filename, "rb").read()
    video_url = f"data:video/mp4;base64,{base64.b64encode(video_file).decode()}"
    return HTML(f'<video width="800" height="600" controls><source src="{video_url}" type="video/mp4"></video>')

# Display the video
display_video('bar_race_chart.mp4')


#codes taken from Youtube channel "Data/Fun" with slight changes
# Out:
# Play the video by clicking on the play button in the bottom left corner
# <video width="800" height="600" controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>

# %%
import pandas as pd
import plotly.express as px

print("Play the video by clicking on play button in bottom left corner. Also keeping mouse pointer on the graph will show the population in each year")

# Sample data
data = {
    'Year': [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030],
    'Aguascalientes': [824227, 844162, 863697, 882995, 902128, 921048, 939507, 957443, 974940, 991858, 1008447, 1025563, 1043783, 1062250, 1079814, 1096736, 1114099, 1133032, 1154011, 1175942, 1195788, 1215094, 1233920, 1252266, 1270174, 1287662, 1304741, 1321453, 1337793, 1353759, 1369306, 1384534, 1399529, 1414225, 1428616, 1442694, 1456433, 1469825, 1482859, 1495544, 1507808],
    'Baja California': [1732550, 1815903, 1895648, 1976271, 2058198, 2141231, 2224286, 2306424, 2387650, 2469220, 2549842, 2627368, 2702832, 2775926, 2845936, 2912674, 2977440, 3041783, 3105709, 3168319, 3224842, 3275399, 3328624, 3381078, 3432944, 3484150, 3534688, 3584606, 3633772, 3682064, 3729227, 3775765, 3822152, 3868004, 3913263, 3957876, 4001753, 4044848, 4087146, 4128624, 4169241],
    'Baja California Sur': [339387, 351246, 363307, 375535, 387994, 400667, 413575, 426653, 439911, 453340, 466455, 480190, 495522, 511831, 529124, 546776, 565024, 584639, 605343, 626900, 649616, 672682, 695410, 718196, 741038, 763930, 786865, 809833, 832827, 855836, 878832, 901820, 924811, 947776, 970702, 993576, 1016375, 1039076, 1061672, 1084143, 1106465],
    'Campeche': [553106, 568384, 583930, 599335, 614694, 629897, 644818, 659417, 673672, 687422, 700708, 714008, 727546, 741113, 754622, 768097, 781620, 795450, 809636, 824071, 836750, 852372, 866375, 880298, 894138, 907878, 921516, 935046, 948461, 961744, 974878, 987876, 1000756, 1013501, 1026110, 1038576, 1050893, 1063055, 1075067, 1086927, 1098636]
}

df = pd.DataFrame(data)

# Create racing bubble chart using Plotly Express
fig = px.scatter(df, x="Year", y="Aguascalientes", size="Aguascalientes", color="Aguascalientes",
                 animation_frame="Year", animation_group="Aguascalientes",
                 size_max=150000, range_x=[1990, 2030], range_y=[800000, 1600000],
                 labels={"Aguascalientes": "Population"},
                 title="Racing Bubble Chart - Population in Aguascalientes Over Time")
fig.update_layout(showlegend=False)

# Show the chart
fig.show()

#codes taken from Chatgpt with slight changes
# Out:
# Play the video by clicking on play button in bottom left corner. Also keeping mouse pointer on the graph will show the population in each year
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a heading
heading1 = "Excecutive Summary:"

# Print the heading with formatting
print(f"\n{'='*len(heading1)}")
print(f"{heading1}")
print(f"{'='*len(heading1)}\n")

Summary = '''
The dataset here provides the population changing over the years in different states of the US. In the first graph we have taken around 9 states to understand the changing population over the years.
The population is increasing in a defined state, no state overtakes the other in terms of population. All the state's population growas in a defined way.The second graph formed showcases the population
of a single state from the year 1990 to 2030.
'''

print(Summary)

heading2 = "Report :"
print(f"\n{'='*len(heading2)}")
print(f"{heading2}")
print(f"{'='*len(heading2)}\n")

Objective = ''' Objective: Analyze and interpret the historical population trends of various states in the United States to identify patterns, variations, and key factors influencing demographic shifts.
 Provide insights into the implications of these changes for policy-makers, urban planners, and stakeholders, aiming to contribute valuable information for informed decision-making and sustainable development strategies.'''
print(Objective)

Report = '''
Observations :
- For the full 1990–2030 period, Distrito Federal has a substantially larger population than any of the other states.
- The population of Distrito Federal and Chiapas, the state with the second-highest population, differs significantly.
- From 1990 to 2030, Distrito Federal continues to be the state with the highest population.
- Distrito Federal's population has grown steadily over time and is still largely stable.
- Chiapas is the second most populated state on a constant basis.
- Despite the significant demographic divide between Chiapas and Distrito Federal, Chiapas is seeing population increase.
- The population of other states is comparatively lower, and there might be variations in their growth patterns.
- It would be interesting to analyze the growth rates and factors influencing population changes in each state.


Managerial Implications:
1. Allocation of Resources:
Given that Distrito Federal is the most populous state, it may be necessary to allocate resources specifically for infrastructure, healthcare, education, and other public services.

2.Development in the Region:
Planning for regional development projects can be made easier by having a thorough understanding of each state's growth patterns.
To mitigate potential discrepancies, states with smaller populations might benefit from focused development initiatives.

3. Planning for Infrastructure:
The most populous district, Distrito Federal, would need careful infrastructure development to accommodate its enormous population.
The second-highest state, Chiapas, may likewise require wise infrastructure investments to support its expanding population.

4. Formulation of Policy:
This data can be used by policymakers to create population-centric policies.
Policies could be adjusted to promote balanced growth in other areas while addressing the unique requirements of states with large populations, like Distrito Federal.

5. Analysis of Demographics:
Additional demographic data, such as trends in urbanisation and age distribution, can offer more insights for more focused and successful policymaking.


'''

print(Report)


# Create a heading
heading3 = "Recommendations:"

# Print the heading with formatting
print(f"\n{'='*len(heading3)}")
print(f"{heading3}")
print(f"{'='*len(heading3)}\n")

insights = '''
1. Urban Planning using a Strategic Approach:
To accommodate the huge and expanding population of Distrito Federal, develop and implement strategic urban planning initiatives.
To meet the requirements of urban dwellers, prioritise affordable housing, sustainable infrastructure, and effective transit networks.

2. Programmes for Regional Development:
Put regional development initiatives into action to address state-by-state differences.
In states with smaller populations, make focused investments to promote economic growth, raise living standards, and draw in enterprises.

3. Investments in Healthcare and Education:
Based on population density, allocate resources for healthcare and education.
Ensure that states with higher populations have appropriate funds and infrastructure to offer quality education and healthcare to their inhabitants.
'''

print(insights)
# Out:
# ...
# Excecutive Summary:
# ...
#
#
# The dataset here provides the population changing over the years in different states of the US. In the first graph we have taken around 9 states to understand the changing population over the years.
# The population is increasing in a defined state, no state overtakes the other in terms of population. All the state's population growas in a defined way.The second graph formed showcases the population
# of a single state from the year 1990 to 2030.
#
#
# ...
# Report :
# ...
#
#  Objective: Analyze and interpret the historical population trends of various states in the United States to identify patterns, variations, and key factors influencing demographic shifts.
#  Provide insights into the implications of these changes for policy-makers, urban planners, and stakeholders, aiming to contribute valuable information for informed decision-making and sustainable development strategies.
#
# Observations :
# ...
